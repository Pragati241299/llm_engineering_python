# %% [markdown]
# # Week 1 - Day 1
#
# Welcome to Day 1! Let's start our learning journey.
#
# ## Topics for Today
# - Introduction and setup
# - Basic concepts
# - Getting familiar with Python

# %% [markdown]
# ## 1. Hello World

# %%
print("Hello from Day 1!")
print("Let's start coding!")

# %% [markdown]
# ## 2. Basic Variables and Data Types

# %%
# Variables
name = "Python Learner"
age = 25
height = 5.9
is_learning = True

# Print variables
print(f"Name: {name}")
print(f"Age: {age}")
print(f"Height: {height}")
print(f"Is Learning: {is_learning}")

# %% [markdown]
# ## 3. Simple Calculations

# %%
# Arithmetic operations
a = 10
b = 5

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")
print(f"Power: {a} ** {b} = {a ** b}")

# %% [markdown]
# ## 4. Your Turn!
#
# Try writing your own code below. Feel free to experiment!

# %%
# Add your code here
