# %% [markdown]
# # Week 1 - Day 2
#
# Great job on Day 1! Now let's dive deeper into Python.
#
# ## Topics for Today
# - Data structures (lists, dictionaries, sets)
# - Control flow (if/else, loops)
# - Functions

# %% [markdown]
# ## 1. Lists

# %%
# Creating a list
fruits = ["apple", "banana", "cherry", "date"]

print("Fruits list:", fruits)
print("First fruit:", fruits[0])
print("Length:", len(fruits))

# Adding to list
fruits.append("elderberry")
print("After append:", fruits)

# %% [markdown]
# ## 2. Dictionaries

# %%
# Creating a dictionary
person = {
    "name": "Alice",
    "age": 28,
    "city": "New York",
    "email": "alice@example.com"
}

print("Person info:", person)
print("Name:", person["name"])
print("Age:", person["age"])

# Adding new key-value pair
person["phone"] = "123-456-7890"
print("Updated:", person)

# %% [markdown]
# ## 3. Control Flow - If/Else

# %%
# If/Else statements
score = 85

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
else:
    grade = "F"

print(f"Score: {score}, Grade: {grade}")

# %% [markdown]
# ## 4. Loops

# %%
# For loop
print("For loop - Numbers:")
for i in range(1, 6):
    print(f"  {i}")

print("\nFor loop - List:")
for fruit in fruits:
    print(f"  {fruit}")

# While loop
print("\nWhile loop:")
count = 0
while count < 3:
    print(f"  Count: {count}")
    count += 1

# %% [markdown]
# ## 5. Functions

# %%
# Define a function
def greet(name, greeting="Hello"):
    """A simple greeting function"""
    return f"{greeting}, {name}!"

# Call the function
print(greet("Alice"))
print(greet("Bob", "Hi"))

# Function with calculation
def calculate_area(length, width):
    """Calculate rectangle area"""
    return length * width

area = calculate_area(5, 10)
print(f"\nArea of rectangle: {area}")

# %% [markdown]
# ## 6. Your Turn!
#
# Try creating your own functions and data structures below!

# %%
# Add your code here
